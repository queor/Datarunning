# %% [markdown]
# # 4.Crawling
#
# 스크레이핑(Scraping)이라고도 하며 웹 페이지 내의 데이터를 추출하는 것을 의미 <br>
# 데이터를 수집하기 위한 방법으로 많이 사용 <br>
# 크게 두 가지의 방법이 존재
# 1. 정적크롤링 <br>
# 정적 데이터를 수집하는 방법 <br>
# 정적 데이터란 페이지 내에 원하는 정보가 모두 들어남
#
# 2. 동적크롤링 <br>
# 동적 데이터를 수집하는 방법 <br>
# 동적 데이터란 클릭, 로그인 등의 행위를 통해 원하는 데이터에 접근 가능 <br>
#
#
# |    |정적 크롤링|동적 크롤링|
# |----|--------|--------|
# |방법 |주소 사용  |브라우저 사용|
# |수집 범위|제한적  |제한 없음|
# |속도|매우 빠름|매우
# <br>
#
# 크롤링 시 사이트에서 크롤링을 허용하는지를 반드시 확인해야 함 <br>
# robots.txt를 뒤에 붙여 확인 가능 <br>
# 강제는 아니나 이를 무시하면 추후 법률적 문제가 생길 수 있음
# ```
# www.daum.net/robots.txt
# User-agent: *
# Disallow: /
# ```
# *: All <br>
# /: All Directories

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## 4.1 HTTP
#
# WWW(World Wide Web, W3) 상에서 정보를 주고받을 수 있는 프로토콜 <br>
# 클라이언트와 서버 사이에 이루어지는 요청/응답 프로토콜

# %% [markdown]
# ### API
# API(Application Programming Interface) <br>
# - Application: 고유한 기능을 가진 모든 소프트웨어
# - Interface: 두 애플리케이션 간의 규약 <br>
# 이 계약은 요청과 응답을 사용하여 두 애플리케이션이 서로 통신하는 방법을 정의합니다.

# %% [markdown]
# ### REST
# REST(Representational State Transfer): 자원을 이름으로 구분하여 해당 자원의 상태를 주고받는 것 <br>
#
# REST 구성
# 1. 자원(Resource): HTTP URI
# 2. 자원에 대한 행위(Verb): HTTP Method
# 3. 자원에 대한 행위의 내용(Representations): HTTP Message Pay Load
#
#
# - HTTP URI(Uniform Resource Identifier)를 통해 자원(Resource)을 명시
# - HTTP Method(POST, GET, PUT, DELETE)를 사용하여 URI에 대한 CRUD Operation을 적용 <br>
# <br>
#
# HTTP Methods
# - GET: 자원 검색
# - POST: 자원 작성
# - PUT: 자원 업데이트
# - DELETE: 데이터 삭제
# - HEAD: 자원 검색 (GET과 유사하나 상태 줄과 헤더만 반환)
# - OPTIONS: 자원이 지원하고 있는 메소드의 취득
# - PATCH: 자원 일부 수정 (PUT과 유사하나 일부만 수정)
# - CONNECT: 자원의 터널 접속을 변경
# - TRACE: 리소스에 대한 경로를 따라 메시지 루프백 테스트를 수행
# <br>
#
# HTTP Status
# 1. 1xx(Informational): 요청 처리중
# 2. 2xx(Successful): 요청 정상 처리 <br>
# 200: 요청 성공
# 3. 3xx(Redirection): 요청을 완료하려면 추가 행동이 필요
# 4. 4xx(Client Error): 클라이언트 오류, 잘못된 문법등으로 요청을 수행할 수 없음 <br>
# 400: Bad Request, 클라이언트의 잘못된 요청으로 서버가 요청을 처리할 수 없음 <br>
# 401: Unauthorized, 해당 리소스에 대한 인증이 필요함 <br>
# 403: Forbidden, 서버가 요청을 이해했지만 승인을 거부함 <br>
# 404: Not Found, 리소스를 찾을 수 없음 <br>
# 5. 5xx(Server Error): 서버 오류

# %% [markdown]
# ### REST API
# REST의 원리를 따르는 API <br>
# ※ RESTful: REST의 원리를 따르는 시스템

# %% [markdown]
# ## 4.2 HTML
# HTML(HyperText Markup Language)은 웹 페이지 표시를 위해 개발된 지배적인 마크업 언어 <br>
# HTML은 웹 페이지 콘텐츠 안의 꺾쇠 괄호에 둘러싸인 "태그"로 되어있는 HTML 요소 형태로 작성 <br>
# HTML은 웹 브라우저와 같은 HTML 처리 장치의 행동에 영향을 주는 자바스크립트, 본문과 그 밖의 항목의 외관과 배치를 정의하는 CSS 같은 스크립트를 포함하거나 불러올 수 있음 <br>
# <br>
# HTML 선택자: HTML에서는 다수의 동일한 태그가 존재하는데 각 태그를 구별할 수 있도록 선택자를 이용
# ```html
# <div>
# 	<div>
#       <a> c </a>
#       <span> c++ </span>
#     </div>
#
#     <div>
#       <a> java </a>
#       <span> python </span>
#     </div>
# </div>
# ```
#
# ```html
# <div id="contents">
# 	<div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %% [markdown]
# ## 4.3 정적크롤링

# %% [markdown]
# #### 4.3.1 라이브러리

# %% [markdown]
# ##### 4.3.1.1 requests
#
# requests: 파이썬용 http 라이브러리 <br>
# reference: https://requests.readthedocs.io/en/latest/
#
# 메소드별 사용법
# ```python
# GET: requests.get()
# POST: requests.post()
# PUT: requests.put()
# DELETE: requests.delete()
# ```
#
# ```python
# import requests
#
# requests.get("https://jsonplaceholder.typicode.com/users/1")
# ```

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://jsonplaceholder.typicode.com/users/1")
bs = BeautifulSoup(response.text, 'lxml')
bs

# %% [markdown]
# ###### Response Body
#
# 요청이 정상적으로 처리가 되면, response body에 요청한 데이터가 담겨져 옴. <br>
# response body 크게 3가지 방식으로 읽을 수 있음 <br>
# 1. content: binary 원문을 읽음
# ```python
# response.content
# ```
# 2. text: utf-8로 인코딩 된 문자열로 읽음
# ```python
# response.text
# ```
# 3. json: 응답이 json이면 dict로 읽음
# ```python
# response.json()
# ```

# %% [markdown]
# ###### Request
#
# param: 주소에 포함된 변수를 담음<br>
# ex) https://www.naver.com/post/12345 <br>
# -> 12345 <br>
# query: 주소 바깥? 이후의 주소를 담음<br>
# ex) https://www.naver.com/post/post_id=12345&id=1 <br>
# -> 12345, 1
# body: XML, JSON 등의 데이터를 담음, 주소에서는 확인 불가<br>
# <br>
#
# requests에서는 아래와 같이 사용
# - get
# ```python
# response = requests.get("https://naver.com/post", params={"post_id": "12345", "id": "1"})
# ```
#
# - post, put: HTML 데이터 전송
# ```python
# response = requests.get("https://naver.com/post", data={"post_id": "12345", "id": "1"})
# ```
# json 형태로도 요청 가능
# ```python
# response = requests.get("https://naver.com/post", json={"post_id": "12345", "id": "1"})
# ```

# %% [markdown]
# ###### headers
#
# 일부 웹 사이트는 bot agent를 차단 <br>
# 이 경우 header의 user-agent를 아래와 같이 넘기면 해결 <br>
# ```python
# requests.get("https://naver.com/post", headers={'User-Agent': 'Mozilla 5.0'})
# ```

# %% [markdown]
# ##### 4.3.1.2 BeautifulSoup
#
# BeautifulSoup: html, xml 등으로부터 원하는 정보를 가지고 올 수 있도록 하는 라이브러리 <br>
# reference: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# ```python
# import requests
# from bs4 import BeautifulSoup
#
# response = requests.get(url)
# bs = BeautifulSoup(response.text, 'lxml')
# ```

# %% [markdown]
# ###### Parser
#
# |parser|특징|설치|속도|사용방법|
# |------|---|---|---|------|
# |html.parser||기본|보통|BeautifulSoup(html_doc, 'html.parser')|
# |lxml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'lxml')|
# |xml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'xml')|
# |html5lib|브라우저와 동일|html5lib 필요|느림|BeautifulSoup(html_doc, 'html5lib')|

# %% [markdown]
# ###### find
# 속성과 값을 이용하여 원하는 값을 찾음
#
# find: 매칭되는 값 중 상위 1개 반환
# find_all: 매칭되는 전체 반환
#
# 특정 태그 추출
# ```python
# soup.find_all('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.find_all(class_='a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.find_all('p', attrs={'class': 'a'}) # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.find_all(id='b') # b id를 갖는 값 추출
# ```
# <br>

# %% [markdown]
# ###### select
# CSS Selector로 태그를 찾아 반환 <br>
# CSS에서 HTML을 태깅하는 방법을 활용 <br>
# <br>
# select_one: 매칭되는 값 중 상위 1개 반환 <br>
# select: 매칭되는 전체 반환 <br>
# <br>
#
# 특정 태그 추출
# ```python
# soup.select('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.select('.a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.select('p.a') # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.select('#b') # b id를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 id 추출
# ```python
# soup.select('p#b') # p 태그와 b id 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 class, id 모두 추출
# ```python
# soup.select('p.a#b') # p 태그와 a 클래스 b id 모두 갖는 값 추출
# ```
# <br>
#
# 특정 태그 아래에 있는 태그 찾기
# ```python
# soup.select('div p') # div 아래 p태그가 있는 값 추출
# soup.select('div > p') # div 바로 아래 p태그가 있는 값 추출
# soup.select("div > #link") # div 바로 아래 link id가 있는 값 추출
# ```
# <br>
#
# 형제 태그 찾기
# ```python
# soup.select("#link + .sister") # link 태그와 형제 태그 중 바로 직후 1개
# soup.select("#link ~ .sister") # link 태그와 형제 태그 중 뒤에 태그 전부
# ```
# <br>
#
# 여러 태그 중 i번째 태그 추출
# ```python
# soup.select('a:nth-of-type(i)') # 추출된 a태그 중 i번째 값 반환
# ```
# <br>
# <br>
#
# 정규표현식 활용 <br>
# ```python
# soup.select('[class~=a]') # class 속성 중 a를 포함하는 태그
# soup.select('a[href]') # a 태그 중 href 속성이 존재하는 태그
# soup.select('a[href="https://www.naver.com"]') # a 태그 중 href 속성이 https://www.naver.com과 매칭되는 태그
# soup.select('a[href^="https://"]') # a 태그 중 href 속성이 https://로 시작하는 태그
# soup.select('a[href$="ac.kr"]') # a 태그 중 href 속성이 ac.kr로 끝나는 태그
# soup.select('a[href*="naver"]') # a 태그 중 href 속성 중 naver를 가지는 태그
# ```
#
# <br>
# <br>
#
# 출력
# ```python
# soup.strings # 값 반환
# soup.stripped_strings # 공백을 제거한 값 반환
# ```

# %% [markdown]
# ### 4.3.2 실습

# %% [markdown]
# ##### 예제
#
# ```html
# <div id="contents">
#     <div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %%
response = '''
<div id="contents"> 
  <div class="data1"> 
      <span class="language"> c++ </span> 
      <span class="language"> java </span> 
      <span class="language"> python </span> 
  </div> 

  <div class="data2"> 
      <a class="framework"> tensorflow </a> 
      <a class="framework"> pytorch </a> 
      <a class="framework"> spring </a> 
  </div> 
</div>
'''

# %%
bs = BeautifulSoup(response, 'lxml')

# %%
bs.select('div')[0]
# Out:
# <div id="contents">
# <div class="data1">
# <span class="language"> c++ </span>
# <span class="language"> java </span>
# <span class="language"> python </span>
# </div>
# <div class="data2">
# <a class="framework"> tensorflow </a>
# <a class="framework"> pytorch </a>
# <a class="framework"> spring </a>
# </div>
# </div>

# %%
bs.select('div')[1]

# %%
bs.select('div')[2]

# %%
bs.select('div')[2].select('a')

# %%
bs.select('div')[2].select('a')[0]

# %%
bs.select('div')[2].select('a')[1]

# %%
bs.select('div')[2].select('a')[2]

# %%
bs.select('div > span')

# %%
bs.select('div > a')
# Out:
# [<a class="framework"> tensorflow </a>,
#  <a class="framework"> pytorch </a>,
#  <a class="framework"> spring </a>]

# %%
bs.select('div > a')[0].text.strip()

# %%
bs.select('div > a')[0].text.strip()

# %%
[tag.text.strip() for tag in bs.select('div > a')]

# %%
bs.select(".data2")
# Out:
# [<div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>]

# %%
bs.select("div")
# Out:
# [<div id="contents">
#  <div class="data1">
#  <span class="language"> c++ </span>
#  <span class="language"> java </span>
#  <span class="language"> python </span>
#  </div>
#  <div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>
#  </div>,
#  <div class="data1">
#  <span class="language"> c++ </span>
#  <span class="language"> java </span>
#  <span class="language"> python </span>
#  </div>,
#  <div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>]

# %% [markdown]
# #### 네이버 뉴스

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# 개별 뉴스

# %%
response = requests.get(
    'https://n.news.naver.com/mnews/article/023/0003759424?sid=101',
    headers = {
    'User-Agent': 'Mozilla 5.0'
    })

bs = BeautifulSoup(response.text, 'lxml')

bs
# Out:
# <!DOCTYPE html>
# <html data-useragent="Mozilla 5.0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="“트위터 유료 구독한 계정 차단하자”...인증 마크 놓고 또 혼란에 빠진 트위터" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/mnews/article/023/0003759424?sid=101" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/023/2023/04/23/0003759424_001_20230423095301032.jpg?type=w800" property="og:image"/>
# <meta content="일론 머스크의 트위터가 유료 구독 인증 마크를 놓고 또 혼란에 빠졌다. 트위터는 지난 20일(현지시각)부터 월 7.99달러짜리 트위터 블루 유료 구독을 하지 않는 사람들의 계정에서 인증 마크인 ‘블루체크’ 표시를 없" property="og:description"/>
# <meta content="조선일보 | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="“트위터 유료 구독한 계정 차단하자”...인증 마크 놓고 또 혼란에 빠진 트위터" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="조선일보" name="twitter:creator"/>
# <meta content="https://imgnews.pstatic.net/image/023/2023/04/23/0003759424_001_20230423095301032.jpg?type=w800" name="twitter:image"/>
# <meta content="일론 머스크의 트위터가 유료 구독 인증 마크를 놓고 또 혼란에 빠졌다. 트위터는 지난 20일(현지시각)부터 월 7.99달러짜리 트위터 블루 유료 구독을 하지 않는 사람들의 계정에서 인증 마크인 ‘블루체크’ 표시를 없" name="twitter:description"/>
# <meta content="gdid=880000ED_000000000000000003759424,service=news,collection=news,section=101" name="napp-site-analysis"/>
# <title>“트위터 유료 구독한 계정 차단하자”...인증 마크 놓고 또 혼란에 빠진 트위터</title>
# <link href="https://static-nnews.pstatic.net/css/min/20230420/news.css" rel="stylesheet"/>
# <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "Mnews.v2";
# 			var g_default_area = "art";
#
# 			var svr = "one-service-r-20230420-230420-160732-7c8957b4bc-ftpvb";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "https://news.naver.com";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
# 				isSubscribe: false,
# 				officeId: "023",
# 				articleId: "0003759424",
# 				sectionId : "101",
# 				gdid: "880000ED_000000000000000003759424",
# 				type: "1",
# 				sectionInfo: {
# 					firstSection: "101",
# 					secondSection: "263",
# 					thirdSection: "000"
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: true,
# 				isPressHome: true,
# 				name : "조선일보",
# 				category : "종합지"
# 			};
#
# 			var refererType = "UNKNOWN";
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setAdDeduplication("article_body_dedup");
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newsend",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20230420/common.min.js"></script>
# </head>
# <body class="n_news_mnews fs2 as_mp_layout">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP" style="position: relative;">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="tab">
# <a class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20230423105027.590";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_scroll_wrapper">
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT"><div class="newsct" id="ct" role="main">
# <div class="media_end_head go_trans">
# <div class="media_end_head_top">
# <a class="media_end_head_top_logo" href="http://www.chosun.com/">
# <img alt="조선일보" class="media_end_head_top_logo_img light_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/09/03/logo_023_6_20200903164340.png" title="조선일보" width=""/>
# <img alt="조선일보" class="media_end_head_top_logo_img dark_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/09/15/dark_logo_023_6_20200915183145.png" title="조선일보" width=""/>
# </a>
# <div class="media_end_head_top_channel _CHANNEL_BUTTON_WRAP" style="display:none;">
# <button class="media_end_head_top_channel_add _CHANNEL_BUTTON" data-clk-add="chmain023" data-clk-remove="chdelete023" data-delay="1000" data-notification="true" data-notification-clk="notru" data-text="구독">구독</button>
# <a class="media_end_head_top_channel_layer _LINK" data-clk="chlook" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_CHANNEL_LAYER_023_0003759424" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>조선일보</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서  주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_end_head_top_channel_layer_link">보러가기</span>
# </a>
# <p class="media_end_head_top_channel_layer" id="_CHANNEL_REMOVE_LAYER_023_0003759424" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>조선일보</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# </div>
# <div class="media_end_head_title">
# <h2 class="media_end_head_headline" id="title_area"><span>“트위터 유료 구독한 계정 차단하자”...인증 마크 놓고 또 혼란에 빠진 트위터</span></h2>
# </div>
# <div class="media_end_head_info nv_notrans">
# <div class="media_end_head_info_datestamp">
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">입력</em><span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2023-04-23 09:52:01">2023.04.23. 오전 9:52</span>
# </div>
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">수정</em><span class="media_end_head_info_datestamp_time _ARTICLE_MODIFY_DATE_TIME" data-modify-date-time="2023-04-23 09:53:01">2023.04.23. 오전 9:53</span>
# </div>
# <a class="media_end_head_origin_link" data-clk="are.ori" data-extra='{"lk":{"oid":"023","aid":"b978eaabad199ceb"}}' data-gdid="023" href="https://www.chosun.com/economy/economy_general/2023/04/23/HF5TJZWM4JDENJ2AUPYUKJJBV4/?utm_source=naver&amp;utm_medium=referral&amp;utm_campaign=naver-news" target="_blank">기사원문</a>
# </div> <div class="media_end_head_journalist">
# <a class="media_end_head_journalist_box" data-clk="ummore" href="https://media.naver.com/journalist/023/74068">
# <div class="media_end_head_journalist_thumb">
# <img height="24" src="https://mimgnews.pstatic.net/image/upload/journalist/2020/05/26/1306300392HX0C00.jpg?type=nf112_112" width="24"/>
# </div>
# <em class="media_end_head_journalist_name">김성민 기자</em>
# </a>
# <div class="media_end_head_journalist_layer _JOURNALIST_CARD" id="_JOURNALIST_LAYER" style="display: none;">
# <ul class="media_end_head_journalist_layer_list">
# <li class="media_end_head_journalist_layer_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# <div class="media_end_head_journalist_layer_div _LIKE_HIDE _LAZY_LOADING_WRAP">
# <div class="media_end_head_journalist_layer_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2020/05/26/1306300392HX0C00.jpg?type=nf112_112" height="38" width="38"/>
# </div>
# <div class="media_end_head_journalist_layer_text _reactionModule" data-ccounttype="period" data-cid="74068" data-sid="JOURNALIST" id="_cheer_74068_layer">
# <div class="media_end_head_journalist_layer_title">
# <em class="media_end_head_journalist_layer_name">김성민 기자</em>
# <div class="media_end_head_journalist_layer_btns _JOURNALIST_ID" data-journalistid="74068">
# <button class="media_end_head_journalist_btn_subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_74068" data-clk="umsubs" type="button">구독</button>
# <button class="media_end_head_journalist_btn_subscribe is_on _UNSUBSCRIBE" data-channelkey="JOURNALIST_74068" data-clk="umunsubs" data-messagevalue="김성민" data-type="journalist" style="display:none;" type="button">구독중</button>
# </div>
# </div>
# <dl class="media_end_head_journalist_layer_subscriber _button" data-ishiddenlabelaszerocount="true" data-ishiddenzerocount="true" data-type="cheer">
# <div class="media_end_head_journalist_layer_definition_wrap _SUBSCRIBE_COUNT_TEXT_WRAP">
# <dt>구독자</dt>
# <dd class="_SUBSCRIBE_COUNT_TEXT" data-maxcount="99999">0</dd>
# </div>
# <div class="media_end_head_journalist_layer_definition_wrap">
# <dt class="_label">응원수</dt>
# <dd class="_count">0</dd>
# </div>
# </dl>
# </div>
# <a class="media_end_head_journalist_layer_link" data-clk="ummore" href="https://media.naver.com/journalist/023/74068">더보기</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="media_end_head_info_variety">
# <div class="media_end_head_info_variety_left" id="commentFontGroup">
# <div class="media_end_head_info_variety_likeit _LIKE_HIDE as_likeit_improve">
# <!-- 좋아요 -->
# <div class="_reactionModule u_likeit nv_notrans" data-cid="ne_023_0003759424" data-sid="NEWS">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face _LIKE_BUTTON" data-clk="RTL.face" data-label="recommend">
# <span class="u_likeit_icons _icons">
# <span class="u_likeit_icon __reaction__zeroface"></span>
# </span>
# <span class="u_likeit_text _count">추천</span>
# </a>
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.wow|RTL.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.touched|RTL.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.analytical|RTL.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.recommend|RTL.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <!-- 좋아요 -->
# </div>
# <div class="media_end_head_info_variety_cmtcount _COMMENT_HIDE">
# <a class="media_end_head_cmtcount_button _COMMENT_COUNT_VIEW" data-clk="rplt" data-max-limit="true" data-zero-allow="false" href="/mnews/article/comment/023/0003759424?sid=101" id="comment_count">댓글</a>
# </div>
# </div>
# <div class="media_end_head_info_variety_right">
# <!-- 요약봇 -->
# <div class="media_end_head_autosummary _auto_summary_wrapper _SUMMARY _LIKE_HIDE" data-articleid="0003759424" data-officeid="023" id="_SUMMARY_BUTTON">
# <a class="media_end_head_autosummary_button _toggle_btn _SUMMARY_BTN" data-clk="sum" href="javascript:;"><span class="blind">본문 요약봇</span></a>
# <div class="media_end_head_autosummary_layer_dimmed _SUMMARY_DIMMED" style="display: none;"></div>
# <div class="media_end_head_autosummary_layer _auto_summary_contents _SUMMARY_LAYER" style="display: none;">
# <div class="media_end_head_autosummary_layer_head">
# <strong class="media_end_head_autosummary_layer_head_tit">본문 요약봇<a class="media_end_head_autosummary_help" data-clk="help" href="https://help.naver.com/alias/news/news_022.naver">도움말</a></strong>
# <span class="media_end_head_autosummary_layer_head_txt">자동 추출 기술로 요약된 내용입니다. 요약 기술의 특성상 본문의 주요 내용이 제외될 수 있어, 전체 맥락을 이해하기 위해서는 기사 본문 전체보기를 권장합니다.</span>
# <a class="media_end_head_autosummary_layer_close _close_button _SUMMARY_CLOSE_BTN" data-clk="close" href="javascript:;"><span class="blind">닫기</span></a>
# </div>
# <div class="media_end_head_autosummary_layer_body">
# <div class="_contents_body _SUMMARY_CONTENT_BODY"></div>
# </div>
# </div>
# </div>
# <!-- TTS -->
# <div class="media_end_head_tts nv_notrans" id="tts_player_div_wrap">
# <button class="media_end_head_tts_run _TTS_SETTING_BTN" data-clk="wtts" title="텍스트 음성 변환 서비스" type="button"><span class="blind">텍스트 음성 변환 서비스 사용하기</span></button>
# <div class="media_end_head_tts_setlayer nv_notrans _TTS_SETTING_LAYER">
# <div class="media_end_head_tts_setlayer_select">
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectGender">
# <em class="media_end_head_tts_option_tit">성별</em>
# <button class="media_end_head_tts_option" data-clk="ttsma" type="button" value="m">남성</button>
# <button class="media_end_head_tts_option" data-clk="ttsfe" type="button" value="f">여성</button>
# </div>
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectSpeed">
# <em class="media_end_head_tts_option_tit">말하기 속도</em>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="3">느림</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="2">보통</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="0">빠름</button>
# </div>
# <p class="media_end_head_tts_desc">이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.</p>
# <button class="media_end_head_tts_apply _TTS_LISTEN_BTN" data-clk="ttsstart" type="button">본문듣기 시작</button>
# </div>
# <button class="media_end_head_tts_setlayer_close _TTS_SETTING_LAYER_CLOSE_BTN" data-clk="ttsclose" type="button"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div id="tts_player_div"></div> <!-- 폰트 사이즈 -->
# <div class="media_end_head_fontsize _font_size_config_wrapper _FONT_WRAP">
# <a class="media_end_head_fontsize_set _font_size_config_toggle_btn _FONT_BUTTON" data-clk="fsz" href="#"><span class="blind">글자 크기 변경하기</span></a>
# <div class="media_end_head_fontsize_setlayer _FONT_LAYER">
# <ul class="media_end_head_fontsize_setlayer_select">
# <li class="media_end_head_fontsize_option1 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">가<em class="blind">1단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">작게</a>
# </li>
# <li class="media_end_head_fontsize_option2 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">가<em class="blind">2단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">보통</a>
# </li>
# <li class="media_end_head_fontsize_option3 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">가<em class="blind">3단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">크게</a>
# </li>
# <li class="media_end_head_fontsize_option4 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">가<em class="blind">4단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">아주크게</a>
# </li>
# <li class="media_end_head_fontsize_option5 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">가<em class="blind">5단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">최대크게</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="media_end_head_share nv_notrans">
# <a class="u_btn_sns_share naver-splugin spi_sns_share nv_notrans _SHARE_BUTTON" data-band-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=blog" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=calendar" data-canonical-url="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;oid=023&amp;aid=0003759424&amp;sid1=001" data-clk="ushr" data-facebook-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/023/2023/04/23/0003759424_001_20230423095301032.jpg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=kakao" data-likecontentsid="ne_023_0003759424" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=mypeople" data-style="type_a" data-title="“트위터 유료 구독한 계정 차단하자”...인증 마크 놓고 또 혼란에 빠진 트위터" data-twitter-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101" href="#" id="spiButton" onclick="return false">
# <span class="naver-splugin-c send_caption"><span class="u_hc">SNS 보내기</span></span>
# </a>
# </div>
# <div class="media_end_head_print">
# <a class="media_end_print_link _PRINT_BUTTON" data-clk="print" data-print-url="/mnews/article/print/023/0003759424" href="#"><span class="blind">인쇄하기</span></a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="newsct_body" id="contents">
# <div class="newsct_article _article_body" id="newsct_article">
# <div class="go_trans _article_content" id="dic_area">
# <span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/023/2023/04/23/0003759424_001_20230423095301032.jpg?type=w647" id="img1"/>
# </div>
# </div><em class="img_desc">일론 머스크의 트위터 계정. 월 8달러를 내면 달아주는 파란색 인증마크가 달려 있다. /AFP 연합뉴스</em></span><br/>										일론 머스크의 트위터가 유료 구독 인증 마크를 놓고 또 혼란에 빠졌다. 트위터는 지난 20일(현지시각)부터 월 7.99달러짜리 트위터 블루 유료 구독을 하지 않는 사람들의 계정에서 인증 마크인 ‘블루체크’ 표시를 없애는 조치에 들어갔는데 반발이 거센 상황이다.<br/><br/>파란색 체크 인증 마크는 트위터 내 계정이 실제 공식 계정인지를 확인해줘 사칭을 방지하는 역할을 했다. 하지만 많은 유명인들이 트위터 유료 구독을 하지 않아 인증 마크를 잃는 상황이 발생했다. 트위터가 지난 20일 비유료 구독자의 인증마크를 삭제하는 조치를 취하면서 교황과 해리포터 저자 JK 롤링, 팝스타 비욘세, 축구선수 크리스티아누 호날두, 래퍼 제이지, 방송인 오프라 윈프리 등이 모두 파란색 체크 마크를 잃었다.<br/><br/>교황의 경우 파란색 인증 마크를 잃었다가 다시 회색 인증 마크를 얻었는데, 머스크는 “교황과 NBA선수 르브론 제임스, 배우 윌리엄 섀트너 3인에 대해서는 직접 내가 돈을 내줬다”고 트위터에 올렸다. 교황은 돈을 내지 않았지만 머스크가 대신 돈을 내고 인증마크를 다시 달아줬다는 것이다.<br/><br/>유명인들이 인증 마크를 잃고, 계정 사칭의 가능성이 높아지자 머스크는 색다른 아이디어를 내놨다. 머스크는 21일(현지시각) 자신의 트위터에 “우리는 (트위터 구독 요금인) 8달러를 내주는 유명인 계정 지키기 펀드(save-a-celebrity fund)를 시작했다”며 “우리는 이 문제를 매우 심각하게 받아들인다”고 했다. 월 7.99달러 구독료를 대신 내주고 유명인들에게 인증 마크를 다시 달아주는 펀드를 시작했다는 것이다. 전날까지 인증 마크를 잃었던 도널드 트럼프 전 대통령, 가수 저스틴 비버, 축구선수 호날두, 비욘세, JK롤링 등 많은 유명인의 계정엔 22일(현지시각) 기준 다시 파란색 인증 마크가 달렸다.<br/><br/>한편 트위터에서는 머스크의 유료화 전략에 반발하며 파란색 인증 마크를 단 사람들의 계정을 차단(블록)하자는 움직임도 나타났다. 지난 21일 트위터에는 ‘블록더블루’라는 계정이 만들어졌다. 트위터에 각종 밈(Meme·트위터에 유행하는 사진이나 영상)을 올리는 유명 트위터 사용자 ‘드릴’도 이에 동참했다. 이들은 파란색 체크 표시가 있는 수십 개의 계정을 한번에 차단하는 동영상을 게시했다.<br/><br/>
# </div>
# </div>
# <div class="byline">
# <p class="byline_p">
# <span class="byline_s">실리콘밸리=김성민 특파원 dori2381@chosun.com</span>
# </p>
# </div>
# <div class="newsct_journalist">
# <div class="newsct_journalist_inner">
# <h4 class="blind">기자 프로필</h4>
# <div class="media_journalistcard _JOURNALIST_CARD _MORE_WRAP">
# <div class="media_journalistcard_inner" id="JOURNALIST_CARD_LIST">
# <div class="media_journalistcard_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# <div class="media_journalistcard_item_inner">
# <div class="media_journalistcard_intro">
# <div class="media_journalistcard_summary">
# <span class="media_journalistcard_summary_press">
# <img alt="조선일보" class="media_journalistcard_summary_press_img light_type" height="24" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/09/03/logo_023_6_20200903164340.png" title=""/>
# <img alt="조선일보" class="media_journalistcard_summary_press_img dark_type" height="24" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/09/15/dark_logo_023_6_20200915183145.png" title=""/>
# </span>
# <div class="media_journalistcard_summary_inner _LAZY_LOADING_WRAP">
# <div class="media_journalistcard_summary_info">
# <a class="media_journalistcard_summary_photo _LAZY_LOADING_ERROR_HIDE" data-clk="mmore" href="https://media.naver.com/journalist/023/74068">
# <div class="media_journalistcard_summary_photo_inner">
# <img alt="" class="media_journalistcard_summary_photo_inner_img _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2020/05/26/1306300392HX0C00.jpg?type=nf112_112" height="40" style="display:none;" width="40"/>
# </div>
# </a>
# <a class="media_journalistcard_summary_text" data-clk="mmore" href="https://media.naver.com/journalist/023/74068">
# <span class="media_journalistcard_summary_name">
# <span class="media_journalistcard_summary_name_inner">
# <em class="media_journalistcard_summary_name_text">김성민 기자</em>
# </span>
# </span>
# </a>
# </div>
# <div class="subscribe_wrap _JOURNALIST_ID" data-journalistid="74068">
# <a class="subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_74068" data-clk="msubs" href="#">
# <span class="subscribe_ico"><span>구독</span></span>
# </a>
# <a class="subscribe on _UNSUBSCRIBE" data-channelkey="JOURNALIST_74068" data-clk="munsubs" data-messagevalue="김성민" data-type="journalist" href="#" style="display:none;">
# <span class="subscribe_ico"><span>구독중</span></span>
# </a>
# </div>
# </div>
# <span class="media_journalistcard_summary_subscribe">
# <span class="media_journalistcard_summary_subscribe_inner _SUBSCRIBE_COUNT_TEXT_WRAP">
# <i class="media_journalistcard_summary_subscribe_item">구독자</i> <em class="media_journalistcard_summary_subscribe_value _SUBSCRIBE_COUNT_TEXT">0</em>
# </span>
# <span class="media_journalistcard_summary_subscribe_inner _LIKE_HIDE">
# <div class="u_likeit_list_module _reactionModule" data-ccounttype="period" data-cid="74068" data-sid="JOURNALIST" id="_cheer_74068_layer">
# <span class="u_likeit_list_btn _button" data-ishiddenlabelaszerocount="true" data-ishiddenzerocount="true" data-type="cheer">
# <em class="u_txt _label">응원수</em>
# <em class="u_cnt _count">0</em>
# </span>
# </div>
# </span>
# </span>
# </div>
# </div>
# <div class="media_journalistcard_word">
# <p class="media_journalistcard_word_text">세상을 그 무엇보다 빠르게 바꿔나가는 IT 산업을 출입하고 있습니다. 세상의 흐름과 놓치지 말아야 할 뉴스, 그 뒷이야기를 파헤치겠습니다.</p>
# </div>
# <div class="media_journalistcard_morenews">
# <ul class="media_journalistcard_morenews_list">
# <li class="media_journalistcard_morenews_item">
# <a class="media_journalistcard_morenews_item_inner" data-clk="bestart" href="/mnews/article/023/0003759178?type=journalists">“처음엔 흥분하지만 모든 걸 빼앗긴다”... 美스타트업, 애플과 ‘죽음의 키스’</a>
# </li>
# <li class="media_journalistcard_morenews_item">
# <a class="media_journalistcard_morenews_item_inner" data-clk="bestart" href="/mnews/article/023/0003759002?type=journalists">스탠퍼드대 찾은 이병헌 “‘기생충’, ‘올드보이’ 출연 못한 것 후회했다”</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="media_journalistcard_recommend media_journalistcard_recommend_is_on" id="_RECOMMEND_JOURNALIST" style="display:none;">
# <div class="media_journalistcard_recommend_inner">
# <h4 class="media_journalistcard_recommend_title _RECOMMEND_JOURNALIST_WRAP">조선일보의 구독 많은 기자</h4>
# <script class="_RECOMMEND_JOURNALIST_TEMPLATE" type="x-tmpl-mustache">
# 							<ul class="media_journalistcard_recommend_list">
# 								{{#list}}
# 								<li class="media_journalistcard_recommend_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# 									<div class="media_journalistcard_recommend_item_inner">
# 										<a href="{{reporterUrl}}" class="media_journalistcard_recommend_item_link" data-clk="bmmore">
# 											{{#imageUrl}}
# 											<span class="media_journalistcard_recommend_img_wrap"><img src="{{imageUrl}}" width="44" height="44" alt="" class="media_journalistcard_recommend_img"></span>
# 											{{/imageUrl}}
# 											<em class="media_journalistcard_recommend_name">{{reporterName}}</em>
# 										</a>
# 										{{#count}}
# 										<span class="media_journalistcard_recommend_subscribe">구독자 <em class="_SUBSCRIBE_COUNT_TEXT">{{count}}</em></span>
# 										{{/count}}
# 										<div class="subscribe_wrap">
# 											<a href="#" class="subscribe _SUBSCRIBE" data-channelKey="{{channelKey}}" data-clk="bmsubs">
# 												<span class="subscribe_ico"><span>구독</span></span>
# 											</a>
# 											<a href="#" class="subscribe on _UNSUBSCRIBE" data-channelKey="{{channelKey}}" data-type="journalist" data-messageValue="{{reporterName}}" data-clk="bmunsubs" style="display:none;">
# 												<span class="subscribe_ico"><span>구독중</span></span>
# 											</a>
# 										</div>
# 									</div>
# 								</li>
# 								{{/list}}
# 							</ul>
# 							</script>
# <div class="media_journalistcard_recommend_channel _JOURNALIST_CHANNEL_PROMOTION">
# <strong>조선일보</strong> 기사를 더 보고 싶다면?
# 								<button class="media_journalistcard_recommend_channel_add _JOURNALIST_CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chsub" data-clk-remove="chsubback" data-delay="1000" data-gdid="023" type="button">구독</button>
# <a class="media_journalistcard_recommend_channel_layer _LINK" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_JOURNALIST_CHANNEL_LAYER_023_0003759424" style="display:none;">
# <span class="media_journalistcard_recommend_channel_layer_text"><strong>조선일보</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서 조선일보 주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_journalistcard_recommend_channel_layer_link">보러가기</span>
# </a>
# <p class="media_journalistcard_recommend_channel_layer" id="_JOURNALIST_CHANNEL_REMOVE_LAYER_023_0003759424" style="display:none">
# <span class="media_journalistcard_recommend_channel_layer_text"><strong>조선일보</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# <a class="media_journalistcard_recommend_close _TOGGLE" data-clk="bmclose" data-target="_RECOMMEND_JOURNALIST" href="#">닫기</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="copyright">
# <div class="c_inner">
# <p class="c_text">Copyright ⓒ 조선일보. All rights reserved. 무단 전재 및 재배포 금지.</p>
# </div>
# </div> <div class="media_end_categorize">
# <a class="media_end_categorize_link _categorize_title _TOGGLE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">이 기사는 언론사에서 <em class="media_end_categorize_item">경제</em> 섹션으로 분류했습니다.</a>
# <div class="media_end_categorize_ct" id="_ARTICLE_SECTION_GUIDE_LAYER">
# <em class="media_end_categorize_ct_title">기사 섹션 분류 안내</em>
# <p class="media_end_categorize_ct_p">기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.</p>
# <a class="media_end_categorize_ct_close _CLOSE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">닫기</a>
# </div>
# </div>
# <div id="channelBanner" style="display:none;">
# <div class="media_end_channel_banner _LAZY_LOADING_WRAP">
# <a class="media_end_channel_banner_link _CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chbanner023" data-clk-remove="chsee023" data-notification="true" data-notification-clk="notbb" href="#">
# <div class="media_end_channel_banner_head _LAZY_LOADING_ERROR_HIDE">
# <div class="media_end_channel_banner_img">
# <img alt="조선일보" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/05/04/logo_023_57_20200504142004.png" height="40" style="display:none;" width="40"/>
# </div>
# </div>
# <div class="media_end_channel_banner_body _before _CHANNEL_BANNER_ADD">
# <p class="media_end_channel_banner_add">구독</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!</span></p>
# </div>
# <div class="media_end_channel_banner_body _after _CHANNEL_BANNER_REMOVE is_hidden">
# <p class="media_end_channel_banner_add is_disabled">구독중</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 확인해보세요!</span> <em>보러가기</em></p>
# </div>
# </a>
# </div>
# </div>
# <div id="channelBannerRecommendList"></div>
# <script class="_CHANNEL_BANNER_RECOMMEND_LIST" type="x-tmpl-mustache">
# 	<div class="office_preference _CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 	<div class="ofpr_recommend">
# 		<div class="ofpr_recommend_inner">
# 			<div class="ofpr_more_link">
# 				<h4 class="ofpr_tit">추가 구독해보세요</h4>
# 			</div>
# 			<ul class="ofpr_channel">
# 				{{#recommendList}}
# 				<li class="ofpr_item">
# 					<a href="#" class="ofpr_a _ALL_OFFICES_ITEM" data-officeId="{{officeId}}" data-officename="{{name}}" data-logo="{{logo}}" role="checkbox" aria-checked="false" data-clk-add="chwith" data-clk-remove="chwithno" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 						<div class="ofpr_thumb"><img src="{{logo}}" class="ofpr_m" alt=""></div>
# 						<div class="ofpr_text">{{name}}</div>
# 						<span class="ofpr_badge">언론사 추가</span>
# 					</a>
# 				</li>
# 				{{/recommendList}}
# 			</ul>
# 			<div class="ofpr_btn_wrap">
# 				<button type="button" class="ofpr_btn_more _ALL_OFFICE_LIST" data-clk="chwithall">언론사 전체보기</button>
# 				<button type="button" class="ofpr_btn_confirm _ALL_OFFICES_COMPLETE disabled" data-clk-disabled="chwithsetall" data-clk-enabled="chwithchoice" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">언론사 전체 선택</button>
# 			</div>
# 			<button type="button" class="ofpr_recommend_close _TOGGLE" data-target="channelBannerRecommendList" data-clk="chclosing">닫기</button>
# 		</div>
# 	</div>
# 	</div>
# 	</script>
# <div class="promotion">
# <ul class="p_list">
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://chosun.app.link/5u5esAtNysb">압도적 1위 칼럼 ‘만물상’ 조선일보 앱에서 보기</a>
# </li>
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://chosun.app.link/hW22NalDBvb">뉴스도 본점이 맛있다! 조선닷컴에서 주요 기사 보기</a>
# </li>
# </ul>
# </div> <div class="media_end_linked">
# <h3 class="media_end_linked_title">
# <a class="media_end_linked_title_inner" href="http://www.chosun.com/">
# <img alt="조선일보" class="media_end_linked_title_img light_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/09/03/logo_023_6_20200903164340.png" title="조선일보" width=""/>
# <img alt="조선일보" class="media_end_linked_title_img dark_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/09/15/dark_logo_023_6_20200915183145.png" title="조선일보" width=""/>
# </a>
# 			주요뉴스<span class="media_end_linked_title_desc">해당 언론사에서 선정하며 <em>언론사 페이지(아웃링크)</em>로 이동해 볼 수 있습니다.</span>
# </h3>
# <ul class="media_end_linked_list">
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"023","aid":"c931e1e53326bcfb"}}' data-gdid="023" href="https://www.chosun.com/economy/real_estate/2023/04/23/DGCSRQQJLVGX5CWDST3U3AVMV4/?utm_source=naver&amp;utm_medium=referral&amp;utm_campaign=naver-related" target="_blank">보증 의무화가 전세 사기 촉발… '전세 대출'의 역설</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"023","aid":"3563335c74c58c9c"}}' data-gdid="023" href="https://www.chosun.com/national/weekend/2023/04/22/6WDXH7FMHRA5LPZRJ6SPVZMQTY/?utm_source=naver&amp;utm_medium=referral&amp;utm_campaign=naver-related" target="_blank">"북한 말로 문건 정리, 노동 고민은 없어… 민노총은 괴물"</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"023","aid":"ba4350e11d4f2ae1"}}' data-gdid="023" href="https://www.chosun.com/national/weekend/2023/04/22/6IYBWTGRUVAUVMKH6LQMWOENSI/?utm_source=naver&amp;utm_medium=referral&amp;utm_campaign=naver-related" target="_blank">고민정 의원을 위한 '문재인 정권 언론 탄압'의 진실</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"023","aid":"57496282ce3a7b3e"}}' data-gdid="023" href="https://www.chosun.com/economy/weeklybiz/2023/04/20/NOAYZSXGRZCH3M2KKKJH2OIL6Y/?utm_source=naver&amp;utm_medium=referral&amp;utm_campaign=naver-related" target="_blank">자율주행 모내기, AI가 병충해탐지… '황금쌀' 탄생</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"023","aid":"baddc256d70a53aa"}}' data-gdid="023" href="https://www.chosun.com/international/international_general/2023/04/22/2UFP5M6EQNA7ZJQKZZQ6YQ6VHU/?utm_source=naver&amp;utm_medium=referral&amp;utm_campaign=naver-related" target="_blank">송영길 "민주당 탈당… 모든 정치적 책임 지겠다"</a></li>
# </ul>
# </div>
# <div class="r_group_comp ad_box _da_banner is_border_none">
# <div class="ad_area _AD_WRAP _PERSIST_HEIGHT" data-article="false" data-mobileonly="false" data-persist="1_ad" data-sync="false" data-unitid="p_news_newsend" id="nmap_c_023_0003759424_101_1"></div>
# </div>
# <script>
# 	window.__htExternalUrl = window.__htExternalUrl || {};
# 	window.__htExternalUrl["like"] = "https://news.like.naver.com/js/reaction/dist/reaction.min.js";
# 	window.__htLikeOption = {
# 		type: "multi",
# 		cssId: "news",
# 		domain: "https://news.like.naver.com",
# 		isMobile: true,
# 		isHiddenLabel: false,
# 		isHiddenCount: false,
# 		isHiddenZeroCount: false,
# 		isUsedLabelAsZeroCount: false,
# 		isDebugMode: false,
# 		isDuplication: false,
# 		isHiddenLayerAfterSelection: true,
# 		clicklog: function(el, name) {
# 			nclkWrap.send({
# 				$this: $(el),
# 				sArea: name
# 			});
# 		}
# 	};
# 	window.__htLikeOption["isZeroFace"] = true;
# 	</script>
# <div class="ends_btn _PERSIST_HEIGHT _LIKE_HIDE as_likeit_improve" data-persist="0_faceLike">
# <div class="ends_btn_head">
# <strong class="ends_head_title">이 기사를 추천합니다</strong>
# <button class="ends_help_btn _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.info" data-target="_LIKE_INFO_LAYER" type="button"></button>
# <div class="ends_help_layer is_hidden" id="_LIKE_INFO_LAYER">
# <p class="ends_help_desc">기사 추천은 24시간 내 50회까지 참여할 수 있습니다.</p>
# <button class="ends_help_close _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.infoclose" data-target="_LIKE_INFO_LAYER"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div class="_reactionModule u_likeit" data-cid="ne_023_0003759424" data-sid="NEWS" id="likeItCountViewDiv" style="visibility: visible;">
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.useful|RTC.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.wow|RTC.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.touched|RTC.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.analytical|RTC.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.recommend|RTC.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <div class="u_likeit_module u_btn_likeit_on" id="likeItSTimeLineShareDiv" style="display:none"></div>
# <div class="u_likeit_module" id="likeItScrollDiv" style="display:none">
# <div class="u_likeit_friends" id="likeItFriendListDiv"></div>
# </div>
# </div> <div class="ends_addition" id="endAdditionContainer">
# <script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["share"] = "https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js";
# 			window.__htShareOption = {
# 				"scriptUrl": window.__htExternalUrl["share"],
# 				"evKey": "news",
# 				"dimmed": "fixed",
# 				"serviceName": "뉴스",
# 				"sourceName": "조선일보"
# 			};
# 			if (isAvailableDarkMode) {
# 				window.__htShareOption["darkMode"] = true;
# 			}
# 		</script>
# <div id="spiLayer" style="display:none;">
# <div class="spi_wrap layer_share_on">
# <div class="spi">
# <div class="spug">
# <a class="naver-splugin _spi_release spi_ico _btn_postbtn sns_share" data-band-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=blog" data-button="postbtn" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=calendar" data-clk="dshr" data-facebook-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/023/2023/04/23/0003759424_001_20230423095301032.jpg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=kakao" data-likecontentsid="ne_023_0003759424" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=mypeople" data-style="type_a" data-title="“트위터 유료 구독한 계정 차단하자”...인증 마크 놓고 또 혼란에 빠진 트위터" data-twitter-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101&amp;lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/023/0003759424?sid=101" href="#"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="tomain_info _LIKE_HIDE" id="_TOMAIN_INFO" style="display: none;">
# <p class="tomain_info_layer">
# <strong class="tomain_info_head">모두에게 보여주고 싶은 기사라면<i>?</i><span class="tomain_info_betaicon">beta</span></strong>
# <span class="tomain_info_body">
# <strong class="tomain_info_point">이 기사를 추천합니다 </strong><span class="tomain_info_text">버튼을 눌러주세요. <br/> 집계 기간 동안 추천을 많이 받은 기사는 네이버 자동 기사배열 영역에 추천 요소로 활용됩니다.</span>
# </span>
# <a class="tomain_info_close _CLOSE" data-target="_TOMAIN_INFO" href="#">레이어 닫기</a>
# </p>
# </div>
# </div> <div class="_VALID_SERIES" data-component-id=""></div>
# <div class="media_end_linked_more">
# <div class="media_end_linked_more_inner">
# <a class="media_end_linked_more_link" data-clk="phome" data-gdid="023" href="https://media.naver.com/press/023"><em class="media_end_linked_more_point">조선일보</em> 언론사홈 바로가기</a>
# </div>
# </div>
# <script>
# 		window.__htExternalUrl = window.__htExternalUrl || {};
# 		window.__htExternalUrl["tip"] = "https://ssl.pstatic.net/dicimg/tip/tip_m.js";
# ...
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ranking_list _FLICKING_CONTENT">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.8639221615149489" href="https://contents.premium.naver.com/mediaschool/teddybae/contents/230417144610317zj?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										국가대표가 알려주는 골고루 복근운동 BEST 3
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA4MThfMjMw/MDAxNjYwODA1MTExMzg1.80xXivTWUKr_Ob-X1mh7OWaKvNjnt5mBRvBkNQbTld8g.M0MvadaFHaCVXpQDrYP9OGEZ4LOJ3t7v2lID2svtPOwg.JPEG/image%7Cpremium%7Cchannel%7Cmediaschool%7C2022%7C08%7C18%7C1660805111119.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">쉐어하우스</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA0MTdfMjg3/MDAxNjgxNzEwMzEwMTU1.tDKv2ht2yyG1mQzeE0GpMvtdcchqSFE91npLUU_Z-SQg.n4wiLYdvy3ms9312JNOn2wKR4tQkQsXBv_Ut9Qfx2O4g.JPEG/abdominal-exercises-001.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="1.0799222532389092" href="https://contents.premium.naver.com/japan114/japanmat/contents/230412180319403jw?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										[오사카/카페] CHINCHA
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjEwMDRfNzAg/MDAxNjY0ODkwNDE3Mjcw.twNvGFn9IqisUKCOx3mPIjQ_3tHMu1iGjQuT82X3gPAg.ldICvj7CsmD5bUNvGQPzZNq0MWz7FPjQffiYjurAp84g.JPEG/image%7Cpremium%7Cchannel%7Cjapan114%7C2022%7C10%7C04%7C1664890417135.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">일본 맛집여행가이드</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA0MTJfOTUg/MDAxNjgxMjg5OTMyNzY4.0_ukK-oyA2x_OnX9KQ7-Roqt2RN8F4yPDwugF7xYJnkg.EHPD71es0Bm2KAsY7qshdaSJvMTbZFCQSmB74D6LE5Yg.JPEG/16-1.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.8161370202012942" href="https://contents.premium.naver.com/youngsmart/youngsmart123/contents/230324113134023jy?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										[영작] 28 I admire the most ~ 가장 존경하는 인물은
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjExMTZfMTIg/MDAxNjY4NTc0MDQyMzIy.JvTmvXlnI4SjsBHuUudpL94ogA898ao49Ndz-twB2QQg.d1t-ha6cnXnC_oofEwCchcOUC-wUZIVy5ipevSpEz_Ag.JPEG/image%7Cpremium%7Cchannel%7Cyoungsmart%7C2022%7C11%7C16%7C1668574042290.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">성장하는 내일 지식</div>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="1.1275286241917715" href="https://contents.premium.naver.com/researchtopic/inquirytopic/contents/230420141835019km?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										교육 뉴스 브리핑 - 2023.04.20
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA5MzBfMTA2/MDAxNjY0NDc4ODMxMjkx.CL7YzxfSjB22wVLiusd2J9uuickBF9qAzTv_9CwgQpgg.So5sInUG6HuQjy3aOjwGyt4XXpyVKNhKRA9J7q--P_kg.JPEG/image%7Cpremium%7Cchannel%7Cresearchtopic%7C2022%7C09%7C30%7C1664478831252.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">학종 전공별 탐구 주제</div>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="pg ra_paginate">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" data-clk="arp.bprv" type="button"><span class="blind">이전 콘텐츠들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="3"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">3</div>
# <button class="pg_btn_next _FLICKING_NEXT" data-clk="arp.bnxt" type="button"><span class="blind">다음 콘텐츠들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 			{{#selected}}
# 			<div class="pg_num pg_num_cur">{{number}}</div>
# 			{{/selected}}
# 		</script>
# </div>
# </div>
# </div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside?oid=023" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%"></iframe>
# 			</script>
# </div>
# </aside>
# </div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# <p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr/>
# <div class="u_ft _STICKY_FOOTER">
# <div class="u_ft_inner">
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <footer role="contentinfo">
# <p class="u_ftlkw" id="u_ftlkw">
# <a class="u_ftlk _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# <a class="u_ftlk _LINK" data-clk="fot.sitemap" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </p>
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra _LINK" data-pc-url="https://news.naver.com/main/ombudsman/index.naver" data-url="https://m.news.naver.com/ombudsman/index" href="https://m.news.naver.com/ombudsman/index">서비스안내</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">뉴스도움말</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a></span>
# </span>
# <span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단<br/>이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER Corp.</a></span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1">조선일보</a></span>
# </p>
# </footer>
# </div>
# </div><div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 기사는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_COMMENT_FOLLOW_TUTORIAL" style="display: none;"></div>
# <script class="_MODAL_COMMENT_FOLLOW_TUTORIAL_TEMPLATE" type="x-tmpl-mustache">
# <div class="comment_follow_tutorial" role="dialog" aria-modal="true">
# 	<div class="comment_follow_tutorial_layer">
# 		<div class="comment_follow_tutorial_layer_dimmed"></div>
# 		<div class="comment_follow_tutorial_layer_container">
# 			<div class="comment_follow_tutorial_layer_content">
# 				<div class="comment_follow_tutorial_layer_item">
# 					<p class="{{className}}">{{text}}</p>
# 					<i class="comment_follow_tutorial_layer_closeicon"></i>
# 					<button type="button" class="comment_follow_tutorial_layer_close _MODAL_COMMENT_FOLLOW_TUTORIAL_CLOSE" data-clk="{{nclkPrefix}}tutclose">닫기</button>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20230420/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20230420/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {"id":"101","name":"경제"};
# 		var redirectSection = {"id":"101","name":"경제"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "http://news.naver.com/main/read.nhn?oid=023&aid=0003759424";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("unload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var fnOnUnload = window.onunload;
# 				window.onunload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				lcs_do_gdid("880000ED_000000000000000003759424");
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": (/\/article\/comment\//.test(location.href) == true) ? "댓글" : "본문",
# 					},
# 					"extraInfo": {
# 						"articleId": article.articleId,
# 						"sectionId": article.sectionId,
# 						"officeId": article.officeId,
# 						"articleType": article.type
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data,
# 						contentBodyEl: document.querySelector("._article_content"),
# 						contentBodyVideoWrapperSelector: "._VIDEO_AREA"
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# </body>
# </html>

# %%
title = bs.select('h2#title_area > span')[0].text.strip()

time = bs.select('span.media_end_head_info_datestamp_time._ARTICLE_DATE_TIME')[0].text.strip()

author = bs.select('em.media_end_head_journalist_name')[0].text.strip()

contents = bs.select('div#dic_area')[0].text.strip()

print(title)

print(time)

print(author)

print(contents)
# Out:
# “트위터 유료 구독한 계정 차단하자”...인증 마크 놓고 또 혼란에 빠진 트위터
# 2023.04.23. 오전 9:52
# 김성민 기자
# 일론 머스크의 트위터 계정. 월 8달러를 내면 달아주는 파란색 인증마크가 달려 있다. /AFP 연합뉴스										일론 머스크의 트위터가 유료 구독 인증 마크를 놓고 또 혼란에 빠졌다. 트위터는 지난 20일(현지시각)부터 월 7.99달러짜리 트위터 블루 유료 구독을 하지 않는 사람들의 계정에서 인증 마크인 ‘블루체크’ 표시를 없애는 조치에 들어갔는데 반발이 거센 상황이다.파란색 체크 인증 마크는 트위터 내 계정이 실제 공식 계정인지를 확인해줘 사칭을 방지하는 역할을 했다. 하지만 많은 유명인들이 트위터 유료 구독을 하지 않아 인증 마크를 잃는 상황이 발생했다. 트위터가 지난 20일 비유료 구독자의 인증마크를 삭제하는 조치를 취하면서 교황과 해리포터 저자 JK 롤링, 팝스타 비욘세, 축구선수 크리스티아누 호날두, 래퍼 제이지, 방송인 오프라 윈프리 등이 모두 파란색 체크 마크를 잃었다.교황의 경우 파란색 인증 마크를 잃었다가 다시 회색 인증 마크를 얻었는데, 머스크는 “교황과 NBA선수 르브론 제임스, 배우 윌리엄 섀트너 3인에 대해서는 직접 내가 돈을 내줬다”고 트위터에 올렸다. 교황은 돈을 내지 않았지만 머스크가 대신 돈을 내고 인증마크를 다시 달아줬다는 것이다.유명인들이 인증 마크를 잃고, 계정 사칭의 가능성이 높아지자 머스크는 색다른 아이디어를 내놨다. 머스크는 21일(현지시각) 자신의 트위터에 “우리는 (트위터 구독 요금인) 8달러를 내주는 유명인 계정 지키기 펀드(save-a-celebrity fund)를 시작했다”며 “우리는 이 문제를 매우 심각하게 받아들인다”고 했다. 월 7.99달러 구독료를 대신 내주고 유명인들에게 인증 마크를 다시 달아주는 펀드를 시작했다는 것이다. 전날까지 인증 마크를 잃었던 도널드 트럼프 전 대통령, 가수 저스틴 비버, 축구선수 호날두, 비욘세, JK롤링 등 많은 유명인의 계정엔 22일(현지시각) 기준 다시 파란색 인증 마크가 달렸다.한편 트위터에서는 머스크의 유료화 전략에 반발하며 파란색 인증 마크를 단 사람들의 계정을 차단(블록)하자는 움직임도 나타났다. 지난 21일 트위터에는 ‘블록더블루’라는 계정이 만들어졌다. 트위터에 각종 밈(Meme·트위터에 유행하는 사진이나 영상)을 올리는 유명 트위터 사용자 ‘드릴’도 이에 동참했다. 이들은 파란색 체크 표시가 있는 수십 개의 계정을 한번에 차단하는 동영상을 게시했다.

# %% [markdown]
# 기사전체 (한 페이지 내용 수집)

# %%
def get_bs_from_url(url):
    response = requests.get(
        url,
        headers = {
        'User-Agent': 'Mozilla 5.0'
        })
    bs = BeautifulSoup(response.text, 'lxml')
    return bs


bs = get_bs_from_url("https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023")

# %%
bs.select('div.list_body.newsflash_body li dt')[1::2][0]
# Out:
#   Cell In[109], line 1
#     bs.select('div.list_body.newsflash_body li dt')[0][1::2]strip()
#                                                             ^
# SyntaxError: invalid syntax

# %%
bs.select('div.list_body.newsflash_body li dt')[1::2][0].select('a')[0].get('href')
# Out:
# 'https://n.news.naver.com/mnews/article/023/0003759432'

# %%
titles = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
urls = [link.select('a')[0].get('href') for link in bs.select('div.list_body.newsflash_body li dt')[1::2]]

# %%
urls = [link.select('a')[0].get('href') for link in bs.select('div.list_body.newsflash_body li dt')[1::2]]

# %%
pd.DataFrame({
    'title': titles,
    'url': urls
})
# Out:
#                                            title  \
# 0        이랜드 스파오,  중국에 직진출.. “글로벌 SPA 브랜드로 거듭난다”
# 1            청년 전·월세 보증금 대출 사기 가담 40대… 징역 ‘10개월’
# 2             中관영매체 “韓 외교 국격 산산조각”… 尹대만 발언 연일 비난
# 3      고맙다며 음료수 들고... 경찰서에 제발로 ‘마약 가방’ 찾으러 온 60대
# 4                  류진 풍산그룹 회장, 전경련 한미재계회의 위원장 선임
# 5               “일산화탄소 중독 추정”...경북 청도 캠핑장서 2명 사상
# 6          “큰 거짓에 약간의 진실...” 학폭 가해자로 지목된 군무원의 항변
# 7               만남 거부하는데도 전 여친 집 찾아간 60대에 징역형 집유
# 8   “트위터 유료 구독한 계정 차단하자”...인증 마크 놓고 또 혼란에 빠진 트위터
# 9        “밤 자르게 칼 좀 달라”더니... 모르는 옆 테이블 손님 목에 ‘휙’
# 10     전세사기에 보증의무화 악용 ...전세·매매 폭등락 부른 ‘전세대출’의 역설
# 11         위험천만 절벽에 인증샷 인파 몰렸다... 中 당국이 내놓은 해결책은
# 12                    “검찰 수사 받겠다” 송영길 회견·일문일답 전문
# 13         송영길 “전대때 캠프 일 일일이 못챙겨…강래구는 참여할 위치 아냐”
# 14      송영길 “민족 화해 사명 갖고 정치”... 당 일각 정계은퇴 요구에 거부
# 15                전쟁터에서 돌아와 또 살인…주민들 떨게 만든 러 죄수들
# 16                    송영길 “민주당 탈당…모든 정치적 책임 지겠다”
# 17          “난 성공한 성폭행범” 한국계 배우 망언에…스티븐 연이 대신 사과
# 18         조종실에 여친 부르고 “술 가져와” 요구…인도 기장의 ‘황당 갑질’
# 19           ‘尹 퇴진집회’ 간 野의원 “총선 1년, 민주당에 힘 모아달라”
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# 5   https://n.news.naver.com/mnews/article/023/000...
# 6   https://n.news.naver.com/mnews/article/023/000...
# 7   https://n.news.naver.com/mnews/article/023/000...
# 8   https://n.news.naver.com/mnews/article/023/000...
# 9   https://n.news.naver.com/mnews/article/023/000...
# 10  https://n.news.naver.com/mnews/article/023/000...
# 11  https://n.news.naver.com/mnews/article/023/000...
# 12  https://n.news.naver.com/mnews/article/023/000...
# 13  https://n.news.naver.com/mnews/article/023/000...
# 14  https://n.news.naver.com/mnews/article/023/000...
# 15  https://n.news.naver.com/mnews/article/023/000...
# 16  https://n.news.naver.com/mnews/article/023/000...
# 17  https://n.news.naver.com/mnews/article/023/000...
# 18  https://n.news.naver.com/mnews/article/023/000...
# 19  https://n.news.naver.com/mnews/article/023/000...

# %% [markdown]
# 페이지 여러개

# %%
total_news = pd.DataFrame(columns = ['title', 'url'])
for page in range(1,8):
    url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023&date=20230422&page={page}'
    bs = get_bs_from_url(url)
    
    titles = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
    urls = [link.select('a')[0].get('href') for link in bs.select('div.list_body.newsflash_body li dt')[1::2]]
    
    news = pd.DataFrame({
    'title': titles,
    'url': urls
    })

    total_news = pd.concat([total_news, news])

total_news
# Out:
#                                                 title  \
# 0   이재명, 尹 겨냥해 “살인수출”… 자유진영 28國, 우크라 군사 지원\n포토\n조선...
# 1   정부, LH 매입임대로 전세사기 주택 우선 매수 추진\n포토\n조선일보\n신문A1면...
# 2                      전쟁터에서 돌아와 또 살인…주민들 떨게 만든 러 죄수들
# 3                          송영길 “민주당 탈당…모든 정치적 책임 지겠다”
# 4                “난 성공한 성폭행범” 한국계 배우 망언에…스티븐 연이 대신 사과
# ..                                                ...
# 3             전세사기꾼 7000억 사업 따낼 때, 인천 공무원이 강원도 옮겨가 총괄
# 4
# 5
# 6
# 7
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# ..                                                ...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# 5   https://n.news.naver.com/mnews/article/023/000...
# 6   https://n.news.naver.com/mnews/article/023/000...
# 7   https://n.news.naver.com/mnews/article/023/000...
#
# [121 rows x 2 columns]

# %% [markdown]
# 특정 날짜 범위

# %%
total_news = pd.DataFrame(columns = ['date','title', 'url'])
for date in tqdm(pd.date_range('20230401', '20230423')):
    date = date.strftime("%Y%m%d")
    
    url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023&date={date}&page=10000'
    bs = get_bs_from_url(url)
    last_page_num = int(bs.select('.paging > strong')[0].text.strip())

    for page in range(1,last_page_num+1):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023&{date}=20230422&page={page}'
        bs = get_bs_from_url(url)
        
        titles = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
        urls = [link.select('a')[0].get('href') for link in bs.select('div.list_body.newsflash_body li dt')[1::2]]
        
        news = pd.DataFrame({
        'date' : date,
        'title': titles,
        'url': urls
        
        })

        total_news = pd.concat([total_news, news])

total_news
# Out:
# 100%|██████████| 23/23 [00:35<00:00,  1.55s/it]
#         date                                        title  \
# 0   20230401              자동차가 게처럼 옆으로 스르륵...팽이처럼 제자리 회전도
# 1   20230401  사우디 문 두드리는 K-스타트업들… 오일 머니로 딥테크 투자하는 ‘기회의 땅’
# 2   20230401                           앵무새도 영상통화로 외로움 달랜다
# 3   20230401       삼성전자, 2분기엔 15년만의 ‘전체 적자’ 가능성… S23까지 부진
# 4   20230401        경찰 부르더니 주머니 뒤적... 필로폰 주사기 보여주며 자수한 남성
# ..       ...                                          ...
# 16  20230423
# 17  20230423
# 18  20230423
# 0   20230423        송영길 “전대때 캠프 일 일일이 못챙겨…강래구는 참여할 위치 아냐”
# 1   20230423     송영길 “민족 화해 사명 갖고 정치”... 당 일각 정계은퇴 요구에 거부
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# ..                                                ...
# 16  https://n.news.naver.com/mnews/article/023/000...
# 17  https://n.news.naver.com/mnews/article/023/000...
# 18  https://n.news.naver.com/mnews/article/023/000...
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
#
# [823 rows x 3 columns]

# %%
total_news = pd.DataFrame(columns = ['oid','date','title', 'url'])
for oid in tqdm(['023','028']):
    for date in pd.date_range('20230401', '20230423'):
        date = date.strftime("%Y%m%d")
        
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&date={date}&page=10000'
        bs = get_bs_from_url(url)
        last_page_num = int(bs.select('.paging > strong')[0].text.strip())

        for page in range(1,last_page_num+1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&{date}=20230422&page={page}'
            bs = get_bs_from_url(url)
            
            titles = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
            urls = [link.select('a')[0].get('href') for link in bs.select('div.list_body.newsflash_body li dt')[1::2]]
            
            news = pd.DataFrame({    
            'date' : date,
            'oid' : oid,
            'title': titles,
            'url': urls
            
            })

            total_news = pd.concat([total_news, news])

total_news
# Out:
# 100%|██████████| 2/2 [00:55<00:00, 27.85s/it]
#     oid      date                                        title  \
# 0   023  20230401              자동차가 게처럼 옆으로 스르륵...팽이처럼 제자리 회전도
# 1   023  20230401  사우디 문 두드리는 K-스타트업들… 오일 머니로 딥테크 투자하는 ‘기회의 땅’
# 2   023  20230401                           앵무새도 영상통화로 외로움 달랜다
# 3   023  20230401       삼성전자, 2분기엔 15년만의 ‘전체 적자’ 가능성… S23까지 부진
# 4   023  20230401        경찰 부르더니 주머니 뒤적... 필로폰 주사기 보여주며 자수한 남성
# ..  ...       ...                                          ...
# 16  028  20230423                               허구와 착시, 그리고 진실
# 17  028  20230423                 자전거 퇴근하다 신호위반 사고…법원 “산재 아니다”
# 18  028  20230423                인공지능 ‘빛의 질주’…따라갈 것인가, 성찰할 것인가
# 19  028  20230423              김성회 전 비서관, ‘MBC가 초상권 침해’ 손배소 패소
# 0   028  20230423                돈봉투 의혹은 ‘송영길 사건’ 아니라 ‘민주당 사건’
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# ..                                                ...
# 16  https://n.news.naver.com/mnews/article/028/000...
# 17  https://n.news.naver.com/mnews/article/028/000...
# 18  https://n.news.naver.com/mnews/article/028/000...
# 19  https://n.news.naver.com/mnews/article/028/000...
# 0   https://n.news.naver.com/mnews/article/028/000...
#
# [1418 rows x 4 columns]

# %% [markdown]
# Naver News Crawler

# %%
def naver_news_crawler(oids,start_date,end_date):     
    total_news = pd.DataFrame(columns = ['oid','date','title', 'url'])

    for oid in tqdm(oids):
        for date in pd.date_range(start_date, end_date):
            date = date.strftime("%Y%m%d")
            
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&date={date}&page=10000'
            bs = get_bs_from_url(url)
            last_page_num = int(bs.select('.paging > strong')[0].text.strip())

            for page in range(1,last_page_num+1):
                url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&{date}=20230422&page={page}'
                bs = get_bs_from_url(url)
                
                titles = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
                urls = [link.select('a')[0].get('href') for link in bs.select('div.list_body.newsflash_body li dt')[1::2]]
                
                news = pd.DataFrame({    
                'date' : date,
                'oid' : oid,
                'title': titles,
                'url': urls
                
                })

                total_news = pd.concat([total_news, news])
    return total_news

# %%
naver_news_crawler(['023','025','028'], '20230421','20230423')
# Out:
# 100%|██████████| 3/3 [00:07<00:00,  2.51s/it]
#     oid      date                                        title  \
# 0   023  20230421              자동차가 게처럼 옆으로 스르륵...팽이처럼 제자리 회전도
# 1   023  20230421  사우디 문 두드리는 K-스타트업들… 오일 머니로 딥테크 투자하는 ‘기회의 땅’
# 2   023  20230421                           앵무새도 영상통화로 외로움 달랜다
# 3   023  20230421       삼성전자, 2분기엔 15년만의 ‘전체 적자’ 가능성… S23까지 부진
# 4   023  20230421        경찰 부르더니 주머니 뒤적... 필로폰 주사기 보여주며 자수한 남성
# ..  ...       ...                                          ...
# 16  028  20230423                               허구와 착시, 그리고 진실
# 17  028  20230423                 자전거 퇴근하다 신호위반 사고…법원 “산재 아니다”
# 18  028  20230423                인공지능 ‘빛의 질주’…따라갈 것인가, 성찰할 것인가
# 19  028  20230423              김성회 전 비서관, ‘MBC가 초상권 침해’ 손배소 패소
# 0   028  20230423                돈봉투 의혹은 ‘송영길 사건’ 아니라 ‘민주당 사건’
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# ..                                                ...
# 16  https://n.news.naver.com/mnews/article/028/000...
# 17  https://n.news.naver.com/mnews/article/028/000...
# 18  https://n.news.naver.com/mnews/article/028/000...
# 19  https://n.news.naver.com/mnews/article/028/000...
# 0   https://n.news.naver.com/mnews/article/028/000...
#
# [506 rows x 4 columns]

# %% [markdown]
# #### 네이버 증권

# %% [markdown]
# #### 다음 증권
